# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('https://storage.googleapis.com/kaggle-competitions-data/kaggle/10370/train.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1535379519&Signature=bl5nAIVHRd97hEi4BV31%2FtgQXNNNFdYhsFLHFYrdrD5yXd%2BJ8296Plk98Cmj1y8T9M7Bm5uGo%2BDE%2BX90NIZ5wOR4PpGqx7zH%2BZOQis4F%2FCR2PsVQM0RNOD9EVmi%2Fpitg1vPCo3G764EQT8%2Btnd%2BT9VKSAm3o4dR080NwoiWRMnfGnnS%2FdMoIonfGeC19MORK6uFKklMdzm9Dt3Ae6s6TW602vhx5ED3fgJZl2w%2Br4MLsrZhl0eZ2tocMNeWSS5gkQSGW6EuMCDIOXEc4iUEQcqUfqy9YzyjtK1uipOVmJpo0OUQgkPiIuonwANkskQn4cFEpUGiUW6eup4ow6reJcg%3D%3D')

# %%
df.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'SalePrice'],
#       dtype='object')

# %%
from matplotlib import pyplot
size = (15, 15)
fig, ax = pyplot.subplots(figsize=size)
sns.heatmap(df.corr())

# %%
#the following variables I want to separate out
#Overall Qual, Year Built, Year Remod/Add, Total Bsmt SF, 1st Flr SF, GR Liv Area, Garage Cars, Garage Area

# %%
df_C = df[['SalePrice', 'Id', 'Overall Qual', 'Year Built', 'Year Remod/Add',
           'Total Bsmt SF', '1st Flr SF']]
df_C.dropna(inplace=True)
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
poly = PolynomialFeatures(include_bias=False)

# %%
#df_C is the numerical dataframe I want to build my model off of.

# %%
features = ['Overall Qual', 'Year Built', 'Year Remod/Add',
           'Total Bsmt SF', '1st Flr SF']
X = df_C[features]
y = df_C['SalePrice']

# %%
X.head()
# Out:
#    Overall Qual  Year Built  Year Remod/Add  Total Bsmt SF  1st Flr SF
# 0             6        1976            2005          725.0         725
# 1             7        1996            1997          913.0         913
# 2             5        1953            2007         1057.0        1057
# 3             5        2006            2007          384.0         744
# 4             6        1900            1993          676.0         831

# %%
X_poly = poly.fit_transform(X)

# %%
pfeatures = poly.get_feature_names(features)

# %%
df_F = pd.DataFrame(X_poly, columns=poly.get_feature_names(pfeatures))

# %%
sns.heatmap(df_F.corr())

# %%
df_F.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2050 entries, 0 to 2049
# Data columns (total 20 columns):
# Overall Qual                    2050 non-null float64
# Year Built                      2050 non-null float64
# Year Remod/Add                  2050 non-null float64
# Total Bsmt SF                   2050 non-null float64
# 1st Flr SF                      2050 non-null float64
# Overall Qual^2                  2050 non-null float64
# Overall Qual Year Built         2050 non-null float64
# Overall Qual Year Remod/Add     2050 non-null float64
# Overall Qual Total Bsmt SF      2050 non-null float64
# Overall Qual 1st Flr SF         2050 non-null float64
# Year Built^2                    2050 non-null float64
# Year Built Year Remod/Add       2050 non-null float64
# Year Built Total Bsmt SF        2050 non-null float64
# Year Built 1st Flr SF           2050 non-null float64
# Year Remod/Add^2                2050 non-null float64
# Year Remod/Add Total Bsmt SF    2050 non-null float64
# Year Remod/Add 1st Flr SF       2050 non-null float64
# Total Bsmt SF^2                 2050 non-null float64
# Total Bsmt SF 1st Flr SF        2050 non-null float64
# 1st Flr SF^2                    2050 non-null float64
# dtypes: float64(20)
# memory usage: 320.4 KB

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-140b55d362ca> in <module>()
# ----> 1 X_Poly.head()
#
# NameError: name 'X_Poly' is not defined

# %%
lr = LinearRegression()
cross_val_score(lr, X_poly, y).mean()
# Out:
# 0.7739978434910474

# %%
ss = StandardScaler()
X_scaled = ss.fit_transform(X)
pd.DataFrame(X_scaled, columns=features)
# Out:
#       Overall Qual  Year Built  Year Remod/Add  Total Bsmt SF  1st Flr SF
# 0        -0.079390    0.141802        0.989083      -0.741124   -1.109022
# 1         0.622115    0.804657        0.608541      -0.322696   -0.634756
# 2        -0.780895   -0.620480        1.084218      -0.002199   -0.271489
# 3        -0.780895    1.136084        1.084218      -1.500081   -1.061091
# 4        -0.079390   -2.377044        0.418271      -0.850182   -0.841617
# 5        -0.079390   -0.189625        0.846380       1.021614    1.824865
# 6        -0.079390    1.102941        1.036650      -1.137295   -0.233649
# 7        -0.780895   -0.421624       -1.199030       0.289365    0.058983
# 8        -0.780895   -0.653623       -1.532004      -0.298214   -0.607007
# 9        -0.780895   -0.090197       -0.723353      -0.040035   -0.314375
# 10       -0.079390   -0.023911       -0.628218      -1.279738   -1.719512
# 11        0.622115    1.102941        0.989083       0.333879    0.109437
# 12       -0.780895   -3.039898        1.084218      -2.354741    0.311252
# 13        1.323620    0.904085        0.751244      -0.218089   -0.511145
# 14        0.622115    1.169226        1.084218       0.652151    0.495408
# 15       -0.780895    1.069798        0.989083       0.827980    0.669473
# 16       -0.780895   -1.846761       -1.627139      -0.965918   -1.363813
# 17       -0.780895   -0.289053       -1.008759       0.140245   -0.110037
# 18       -0.079390    0.174945       -0.342812      -0.885793    0.303684
# 19        0.622115    1.235512        1.179353      -0.672128   -1.010637
# 20       -0.780895   -0.123339       -0.770921      -0.364984   -0.682687
# 21        1.323620    0.937227        0.751244       0.986003    1.247169
# 22        1.323620    1.102941        1.036650       0.336105    0.111959
# 23       -0.079390    0.672086        1.084218       0.244852    0.056460
# 24       -0.780895   -0.554195       -1.389301      -0.004424   -0.274012
# 25       -0.079390   -0.355338       -1.103895       0.879170    0.727495
# 26       -0.780895   -0.222768        1.179353      -0.364984   -0.682687
# 27       -0.780895   -1.150764        0.513406      -0.258152    0.253230
# 28       -0.780895   -2.542758        1.036650      -0.224766   -0.329511
# 29       -0.780895   -0.753051        1.036650      -0.859085   -1.242724
# ...            ...         ...             ...            ...         ...
# 2020      0.622115    1.102941        0.989083      -0.609809   -0.960183
# 2021     -0.079390   -0.090197       -0.723353       1.749411    1.713866
# 2022      0.622115    1.102941        0.989083       0.687762    0.510544
# 2023      0.622115    0.241230       -0.247677      -1.155100   -0.314375
# 2024      1.323620    1.136084        1.036650      -0.008876   -0.279057
# 2025      0.622115   -1.482191        0.370703      -0.460688   -0.750800
# 2026     -0.780895   -0.388481       -1.151462       1.108415    0.987332
# 2027      0.622115   -0.123339        0.893947       1.135123    2.500945
# 2028      2.025124    1.169226        1.084218       2.047652    2.051907
# 2029     -1.482399   -2.377044       -1.627139      -0.442883   -0.770981
# 2030     -0.780895   -0.023911        1.131785       0.044541   -0.218513
# 2031     -0.079390    0.174945       -0.342812       0.411778    0.303684
# 2032      1.323620    0.572658        0.228000       0.296042    0.066551
# 2033     -0.079390    0.837799        0.608541       0.937038    0.830925
# 2034     -1.482399   -1.647904       -1.627139      -0.796766    0.038801
# 2035      1.323620    1.136084        1.036650      -0.351630   -0.644847
# 2036     -0.780895    0.075517       -0.485515      -0.431755   -0.682687
# 2037     -0.079390   -0.222768       -0.913624      -0.035584   -0.309330
# 2038     -1.482399   -0.057054       -0.675786      -1.139521   -1.560583
# 2039      0.622115   -0.620480       -1.484436       0.547544    0.351615
# 2040      2.025124    1.036656        0.941515       1.144026    1.027695
# 2041     -1.482399   -1.647904       -1.627139      -0.431755   -0.506099
# 2042     -0.079390   -1.084478       -1.627139      -1.019334   -1.404176
# 2043     -0.079390    0.771514        0.513406      -0.676579   -1.035864
# 2044      1.323620    1.202369        1.131785       1.945271    1.935863
# 2045      1.323620    1.169226        1.084218       1.838438    1.421234
# 2046     -1.482399   -1.051335       -1.627139      -0.438432   -0.765936
# 2047     -0.079390   -1.449048       -1.627139      -0.360533    0.018620
# 2048     -1.482399   -0.521052       -1.341733       0.316074    0.089255
# 2049      0.622115    0.904085        0.703677      -0.142416   -0.344647
#
# [2050 rows x 5 columns]

# %%
#df_C['SalePrice'].isna().sum
#df_C['Id'] = df['Id']

# %%
dfb = df_F[['Overall Qual^2', 'Overall Qual Year Built', 'Overall Qual Year Remod/Add', 'Year Built^2','Overall Qual']]

# %%
X = df_F[['Overall Qual^2', 'Overall Qual Year Built', 'Overall Qual Year Remod/Add', 'Year Built^2','Overall Qual']]
y = df_C['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
lr = LinearRegression()

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)

scores = cross_val_score(lr, X_train, y_train, cv=kf)
scores.mean()
# Out:
# 0.7168430010785418

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lr.score(X,y)
# Out:
# 0.7056738780317448

# %%
import math
import numpy as np
from sklearn.metrics import mean_squared_error as mse

y_hat = lr.predict(X)
df_C['y_hat'] = y_hat

#A:
np.sqrt(mse(y, y_hat))
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 42981.732469891664

# %%
df_C.head()
# Out:
#    SalePrice   Id  Overall Qual  Year Built  Year Remod/Add  Total Bsmt SF  \
# 0     130500  109             6        1976            2005          725.0
# 1     220000  544             7        1996            1997          913.0
# 2     109000  153             5        1953            2007         1057.0
# 3     174000  318             5        2006            2007          384.0
# 4     138500  255             6        1900            1993          676.0
#
#    1st Flr SF          y_hat
# 0         725  171342.898169
# 1         913  218059.752513
# 2        1057  134816.122154
# 3         744  147973.818949
# 4         831  147458.175156

# %%
lr.predict(X)
# Out:
# array([171342.89816933, 218059.75251303, 134816.12215387, ...,
#        141410.18986689, 106373.22251939, 219655.87901354])

# %%
np.sqrt(mse(y, y_hat))
# Out:
# 42981.732469891664

# %%
df_S = df_C[['Id', 'y_hat']]

# %%
df_S
# Out:
#         Id          y_hat
# 0      109  171342.898169
# 1      544  218059.752513
# 2      153  134816.122154
# 3      318  147973.818949
# 4      255  147458.175156
# 5      138  167731.925820
# 6     2827  179454.585979
# 7      145  123813.634417
# 8     1942  120268.255655
# 9     1956  128884.855897
# 10    1044  159395.309175
# 11    2752  223578.246721
# 12     807  117039.246343
# 13    1177  276573.073375
# 14    1480  224886.304475
# 15     324  146953.405671
# 16    1311  110934.121728
# 17     770  125841.220231
# 18    2063  162873.796973
# 19      69  226194.663155
# 20    2062  128377.395207
# 21     351  276882.439062
# 22    2393  280926.682103
# 23      12  176262.401929
# 24    2339  121787.252307
# 25     624  153603.848032
# 26      86  138296.775982
# 27    1534  127765.157381
# 28    2243  120399.273543
# 29    1957  133571.635017
# ...    ...            ...
# 2021  2810  223578.246721
# 2022  2872  158236.415095
# 2023  1072  223578.246721
# 2024  1654  206600.880175
# 2025  2394  281236.499179
# 2026  2212  196461.428855
# 2027  2628  124320.418024
# 2028  2526  212174.918265
# 2029   969  351535.265060
# 2030   306   92552.157331
# 2031    25  139521.105784
# 2032   311  162873.796973
# 2033   300  268907.029657
# 2034  2775  174488.316482
# 2035  2862   97463.383018
# 2036   525  281236.499179
# 2037  2730  131423.287817
# 2038  1892  155919.529711
# 2039  2288  112465.650301
# 2040  2728  189674.370110
# 2041  1065  348812.516100
# 2042  2842   97463.383018
# 2043  2011  144321.508434
# 2044  1140  173325.510365
# 2045  1051  282688.454403
# 2046  1587  281962.439175
# 2047   785  101508.741914
# 2048   916  141410.189867
# 2049   639  106373.222519
# 2050    10  219655.879014
#
# [2050 rows x 2 columns]

# %%
test_kaggle = pd.read_csv('https://storage.googleapis.com/kaggle-competitions-data/kaggle/10370/test.csv?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1535380410&Signature=oDLQWCdV3gb6JcR%2Fo1URHcoi1k4OvGz1Y%2B19UjDFZXE1h3zaQR1QlEij0HsNtOKVH%2FuW8aTjtfUzhcJOC1vynHXXKs6MLZAKMKVUY374k31Y3Z0YNmGNEVoAQaTOKNoQgGilD%2FeUGL5XpI1VEXpe2ozL1AkFpdx880MzGubkdi6AgDsEnc02Gt3gvwQ6XTiRI%2FQmtzvfeNxpDQnoY%2FebptnUnpPAuP%2FUvO0iIw8ipqzSwxCwEGaEo100uidrIb85dlJgl%2FROsymnBaIEtgGdAcW7CiKgAI5HBo38rh0qWykV4Dp562AsAscp0vV3Vp%2F69ObRIsYs0japJFZeZCsZtQ%3D%3D')

# %%
test_kaggle.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour    ...     3Ssn Porch Screen Porch Pool Area  \
# 0  Grvl       Reg          Lvl    ...              0            0         0
# 1   NaN       IR1          Lvl    ...              0            0         0
# 2   NaN       IR1          Lvl    ...              0            0         0
# 3   NaN       Reg          Lvl    ...              0            0         0
# 4   NaN       IR1          Lvl    ...              0          185         0
#
#   Pool QC Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0     NaN   NaN          NaN        0       4     2006        WD
# 1     NaN   NaN          NaN        0       8     2006        WD
# 2     NaN   NaN          NaN        0       9     2006        New
# 3     NaN   NaN          NaN        0       7     2007        WD
# 4     NaN   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %%
ktest = test_kaggle[['Id', 'Overall Qual', 'Year Built', 'Year Remod/Add',
           'Total Bsmt SF', '1st Flr SF', 'Gr Liv Area', 'Garage Cars', 'Garage Area']]

# %%
ktest['totalsqft'] = ktest['Total Bsmt SF'] + ktest['1st Flr SF']
# Out:
# /anaconda3/envs/dsi/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
b = ktest[['Overall Qual', 'Year Built', 'Year Remod/Add',
           'Total Bsmt SF', '1st Flr SF', 'totalsqft']]

# %%
SalePrice = lr.predict(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-82b46f0b5c5b> in <module>()
# ----> 1 SalePrice = lr.predict(b)
#
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     254             Returns predicted values.
#     255         """
# --> 256         return self._decision_function(X)
#     257
#     258     _preprocess_data = staticmethod(_preprocess_data)
#
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     239         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     240         return safe_sparse_dot(X, self.coef_.T,
# --> 241                                dense_output=True) + self.intercept_
#     242
#     243     def predict(self, X):
#
# /anaconda3/envs/dsi/lib/python3.6/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     138         return ret
#     139     else:
# --> 140         return np.dot(a, b)
#     141
#     142
#
# ValueError: shapes (879,6) and (5,) not aligned: 6 (dim 1) != 5 (dim 0)

# %%
ktest['SalePrice'] = SalePrice

# %%
ktest = ktest[['Id', 'SalePrice']]

# %%
ktest.head()

# %%
ktest.to_csv('Good6.csv', sep=',', index=False)

# %%
ktest.shape
